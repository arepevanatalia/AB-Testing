# %% [markdown]
# <a href="https://colab.research.google.com/github/arepevanatalia/AB-Testing/blob/main/%D0%98%D1%82%D0%BE%D0%B3%D0%BE%D0%B2%D0%B0%D1%8F_7_4_M7_HW_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p style="align: center;"><img align=center src="https://mailfit.com/wp-content/uploads/2019/11/lego-5.png"  width=900></p>
# <h1 style="text-align: center;"><b>«Домашняя работа» - Ускорение тестирования</b></h3>

# %% [markdown]
# ## Импорт библиотек

# %%
import numpy as np
import pandas as pd

import scipy

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %% [markdown]
# ## Импорт данных

# %%
data_path = "https://raw.githubusercontent.com/a-milenkin/Datasetes_for_Piplines/main/SkillBox/ab_speedup.csv"
data = pd.read_csv(data_path, index_col=0)
print("Размеры датасета", data.shape)
data.head(20)
# Out:
# Размеры датасета (50000, 2)
#           group    metrica
# strata
# 11      history  42.631346
# 6       history  14.844453
# 4       history   2.362768
# 37      history  79.494017
# 18      history -22.627788
# 34      history  28.679378
# 9       history  20.875503
# 16      history  19.505496
# 43      history -34.727193
# 15      history  26.712643
# 20      history  37.334197
# 25      history  18.156054
# 0       history  10.839549
# 45      history -47.720660
# 9       history  24.201786
# 23      history   6.165731
# 35      history  74.380890
# 21      history  22.357159
# 46      history -43.392082
# 22      history  15.165873

# %% [markdown]
# <div class="alert alert-info">
# <b>Про Датасет</b>
#
# Датасет представляет собой результаты некоторого А/B-Теста.
#
# * `strata` - Некоторая информация по страту (группа), к которой относится пользователь.
# * `group` - Группа эксперимента - тестовая, контрольная или прошлая история.
# * `metrica` - Целивая метрика
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# <b>Задание:</b>
#
# Найти различие между группами, увеличив чувствительность тестов тремя способами поочередно:
# * Бутстрап
# * Стратификация
# * CUPED
#
# Вспомогательная статья Валерия Бабушкина про стратификацию и CUPED:
#
# * habr.com/ru/company/yandex/blog/497804/

# %%
data = data.drop_duplicates()
print("Размер датасета после удаления дубликатов:", data.shape)
# Out:
# Размер датасета после удаления дубликатов: (50000, 2)

# %%
data = data.dropna(axis=1)
print("Размер датасета после удаления столбцов с пропусками:", data.shape)
# Out:
# Размер датасета после удаления столбцов с пропусками: (50000, 2)

# %%
from scipy import stats
from tqdm import tqdm

def calculate_stats(group):
    return group['metrica'].mean(), group['metrica'].std(), len(group)

def perform_t_test(control, test):
    mean_control, std_control, n_control = calculate_stats(control)
    mean_test, std_test, n_test = calculate_stats(test)

    if n_control == 0 or n_test == 0:
        return np.nan, np.nan

    t_statistic = (mean_test - mean_control) / np.sqrt((std_control**2 / n_control) + (std_test**2 / n_test))

    degrees_freedom = ((std_control**2 / n_control) + (std_test**2 / n_test))**2 / \
                      ((std_control**2 / n_control)**2 / (n_control - 1) + (std_test**2 / n_test)**2 / (n_test - 1))

    p_value = 2 * (1 - stats.t.cdf(abs(t_statistic), data=degrees_freedom))

    return t_statistic, p_value

control_group = data[data['group'] == 'control']
test_group = data[data['group'] == 'test']

t_statistic_base, p_value_base = perform_t_test(control_group, test_group)
print("Базовый A/B-тест:")
print(f"t-статистика: {t_statistic_base:.3f}")
print(f"p-значение: {p_value_base:.3f}")

print("\n--------------------------------------------------\n")
# Out:
# Базовый A/B-тест:
# t-статистика: nan
# p-значение: nan
#
# --------------------------------------------------

# %%
print(f"Размер контрольной группы: {len(control_group)}")
print(f"Размер тестовой группы: {len(test_group)}")
print(f"Количество уникальных значений в контрольной группе: {control_group['metrica'].nunique()}")
print(f"Количество уникальных значений в тестовой группе: {test_group['metrica'].nunique()}")


t_statistic_base, p_value_base = perform_t_test(control_group, test_group)
print("Базовый A/B-тест:")
print(f"t-статистика: {t_statistic_base:.3f}")
print(f"p-значение: {p_value_base:.3f}")

print("\n--------------------------------------------------\n")

def bootstrap_test(control, test, n_iterations=1000, random_state=None):
    """
    Проводит бутстрап-тест для сравнения двух групп.  Улучшенная обработка пустых выборок.
    """
    if random_state is not None:
        np.random.seed(random_state)

    # 1. Смещаем данные: вычитаем среднее из каждой группы
    control_shifted = control['metrica'] - control['metrica'].mean()
    test_shifted = test['metrica'] - test['metrica'].mean()

    observed_difference = test['metrica'].mean() - control['metrica'].mean()

    differences = []
    valid_iterations = 0
    for i in tqdm(range(n_iterations), desc="Бутстрап"):
        # 2. Бутстрапируем *смещенные* данные
        boot_control = np.random.choice(control_shifted, size=len(control_shifted), replace=True)
        boot_test = np.random.choice(test_shifted, size=len(test_shifted), replace=True)

        # 3. Проверяем, что бутстрапированные выборки не пустые и не содержат только нули
        if len(boot_control) == 0 or len(boot_test) == 0 or np.all(boot_control == 0) or np.all(boot_test == 0):

            print(f"Итерация {i}: Пустая или нулевая бутстрап-выборка. Пропускаем.")
            continue

        # 4. Считаем разницу средних *бутстрапированных* выборок и *добавляем наблюдаемую разницу*
        diff = np.mean(boot_test) - np.mean(boot_control) + observed_difference
        differences.append(diff)
        valid_iterations += 1

    # 5. Считаем p-value, если были валидные итерации
    if valid_iterations > 0:
        p_value = np.mean(np.abs(differences) >= np.abs(observed_difference))
    else:
        p_value = np.nan

    return observed_difference, p_value

print("Бутстрап:")
observed_difference_boot, p_value_boot = bootstrap_test(control_group, test_group, random_state=42)
print(f"Наблюдаемая разница средних: {observed_difference_boot:.3f}")
print(f"p-значение: {p_value_boot:.3f}")

print("\n--------------------------------------------------\n")
# Out:
# Размер контрольной группы: 0
# Размер тестовой группы: 0
# Количество уникальных значений в контрольной группе: 0
# Количество уникальных значений в тестовой группе: 0
# Базовый A/B-тест:
# t-статистика: nan
# p-значение: nan
#
# --------------------------------------------------
#
# Бутстрап:
# Бутстрап: 100%|██████████| 1000/1000 [00:00<00:00, 15643.73it/s]
# Итерация 0: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 1: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 2: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 3: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 4: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 5: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 6: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 7: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 8: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 9: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 10: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 11: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 12: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 13: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 14: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 15: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 16: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 17: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 18: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 19: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 20: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 21: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 22: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 23: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 24: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 25: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 26: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 27: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 28: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 29: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 30: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 31: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 32: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 33: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 34: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 35: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 36: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 37: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 38: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 39: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 40: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 41: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 42: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 43: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 44: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 45: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 46: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 47: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 48: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 49: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 50: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 51: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 52: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 53: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 54: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 55: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 56: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 57: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 58: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 59: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 60: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 61: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 62: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 63: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 64: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 65: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 66: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 67: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 68: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 69: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 70: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 71: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 72: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 73: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 74: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 75: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 76: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 77: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 78: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 79: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 80: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 81: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 82: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 83: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 84: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 85: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 86: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 87: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 88: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 89: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 90: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 91: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 92: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 93: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 94: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 95: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 96: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 97: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 98: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 99: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 100: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 101: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 102: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 103: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 104: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 105: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 106: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 107: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 108: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 109: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 110: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 111: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 112: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 113: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 114: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 115: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 116: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 117: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 118: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 119: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 120: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 121: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 122: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 123: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 124: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 125: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 126: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 127: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 128: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 129: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 130: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 131: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 132: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 133: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 134: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 135: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 136: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 137: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 138: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 139: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 140: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 141: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 142: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 143: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 144: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 145: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 146: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 147: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 148: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 149: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 150: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 151: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 152: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 153: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 154: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 155: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 156: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 157: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 158: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 159: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 160: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 161: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 162: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 163: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 164: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 165: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 166: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 167: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 168: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 169: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 170: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 171: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 172: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 173: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 174: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 175: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 176: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 177: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 178: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 179: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 180: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 181: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 182: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 183: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 184: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 185: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 186: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 187: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 188: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 189: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 190: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 191: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 192: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 193: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 194: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 195: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 196: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 197: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 198: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 199: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 200: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 201: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 202: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 203: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 204: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 205: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 206: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 207: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 208: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 209: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 210: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 211: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 212: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 213: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 214: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 215: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 216: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 217: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 218: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 219: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 220: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 221: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 222: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 223: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 224: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 225: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 226: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 227: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 228: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 229: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 230: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 231: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 232: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 233: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 234: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 235: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 236: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 237: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 238: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 239: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 240: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 241: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 242: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 243: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 244: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 245: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 246: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 247: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 248: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 249: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 250: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 251: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 252: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 253: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 254: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 255: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 256: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 257: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 258: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 259: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 260: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 261: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 262: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 263: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 264: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 265: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 266: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 267: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 268: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 269: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 270: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 271: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 272: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 273: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 274: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 275: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 276: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 277: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 278: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 279: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 280: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 281: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 282: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 283: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 284: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 285: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 286: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 287: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 288: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 289: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 290: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 291: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 292: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 293: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 294: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 295: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 296: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 297: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 298: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 299: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 300: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 301: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 302: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 303: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 304: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 305: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 306: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 307: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 308: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 309: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 310: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 311: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 312: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 313: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 314: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 315: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 316: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 317: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 318: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 319: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 320: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 321: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 322: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 323: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 324: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 325: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 326: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 327: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 328: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 329: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 330: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 331: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 332: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 333: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 334: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 335: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 336: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 337: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 338: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 339: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 340: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 341: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 342: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 343: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 344: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 345: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 346: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 347: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 348: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 349: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 350: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 351: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 352: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 353: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 354: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 355: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 356: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 357: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 358: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 359: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 360: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 361: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 362: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 363: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 364: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 365: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 366: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 367: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 368: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 369: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 370: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 371: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 372: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 373: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 374: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 375: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 376: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 377: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 378: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 379: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 380: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 381: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 382: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 383: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 384: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 385: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 386: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 387: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 388: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 389: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 390: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 391: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 392: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 393: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 394: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 395: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 396: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 397: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 398: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 399: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 400: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 401: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 402: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 403: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 404: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 405: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 406: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 407: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 408: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 409: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 410: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 411: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 412: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 413: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 414: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 415: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 416: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 417: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 418: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 419: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 420: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 421: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 422: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 423: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 424: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 425: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 426: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 427: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 428: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 429: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 430: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 431: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 432: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 433: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 434: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 435: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 436: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 437: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 438: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 439: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 440: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 441: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 442: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 443: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 444: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 445: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 446: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 447: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 448: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 449: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 450: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 451: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 452: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 453: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 454: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 455: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 456: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 457: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 458: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 459: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 460: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 461: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 462: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 463: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 464: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 465: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 466: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 467: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 468: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 469: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 470: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 471: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 472: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 473: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 474: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 475: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 476: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 477: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 478: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 479: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 480: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 481: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 482: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 483: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 484: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 485: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 486: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 487: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 488: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 489: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 490: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 491: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 492: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 493: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 494: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 495: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 496: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 497: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 498: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 499: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 500: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 501: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 502: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 503: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 504: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 505: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 506: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 507: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 508: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 509: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 510: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 511: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 512: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 513: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 514: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 515: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 516: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 517: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 518: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 519: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 520: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 521: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 522: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 523: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 524: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 525: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 526: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 527: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 528: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 529: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 530: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 531: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 532: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 533: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 534: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 535: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 536: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 537: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 538: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 539: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 540: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 541: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 542: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 543: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 544: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 545: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 546: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 547: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 548: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 549: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 550: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 551: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 552: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 553: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 554: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 555: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 556: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 557: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 558: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 559: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 560: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 561: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 562: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 563: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 564: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 565: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 566: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 567: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 568: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 569: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 570: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 571: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 572: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 573: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 574: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 575: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 576: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 577: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 578: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 579: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 580: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 581: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 582: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 583: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 584: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 585: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 586: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 587: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 588: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 589: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 590: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 591: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 592: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 593: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 594: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 595: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 596: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 597: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 598: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 599: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 600: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 601: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 602: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 603: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 604: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 605: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 606: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 607: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 608: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 609: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 610: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 611: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 612: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 613: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 614: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 615: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 616: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 617: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 618: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 619: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 620: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 621: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 622: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 623: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 624: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 625: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 626: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 627: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 628: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 629: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 630: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 631: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 632: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 633: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 634: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 635: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 636: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 637: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 638: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 639: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 640: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 641: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 642: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 643: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 644: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 645: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 646: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 647: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 648: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 649: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 650: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 651: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 652: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 653: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 654: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 655: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 656: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 657: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 658: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 659: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 660: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 661: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 662: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 663: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 664: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 665: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 666: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 667: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 668: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 669: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 670: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 671: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 672: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 673: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 674: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 675: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 676: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 677: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 678: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 679: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 680: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 681: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 682: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 683: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 684: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 685: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 686: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 687: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 688: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 689: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 690: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 691: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 692: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 693: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 694: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 695: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 696: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 697: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 698: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 699: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 700: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 701: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 702: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 703: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 704: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 705: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 706: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 707: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 708: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 709: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 710: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 711: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 712: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 713: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 714: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 715: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 716: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 717: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 718: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 719: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 720: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 721: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 722: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 723: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 724: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 725: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 726: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 727: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 728: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 729: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 730: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 731: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 732: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 733: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 734: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 735: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 736: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 737: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 738: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 739: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 740: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 741: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 742: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 743: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 744: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 745: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 746: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 747: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 748: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 749: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 750: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 751: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 752: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 753: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 754: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 755: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 756: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 757: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 758: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 759: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 760: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 761: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 762: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 763: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 764: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 765: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 766: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 767: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 768: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 769: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 770: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 771: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 772: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 773: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 774: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 775: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 776: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 777: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 778: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 779: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 780: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 781: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 782: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 783: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 784: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 785: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 786: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 787: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 788: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 789: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 790: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 791: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 792: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 793: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 794: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 795: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 796: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 797: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 798: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 799: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 800: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 801: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 802: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 803: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 804: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 805: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 806: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 807: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 808: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 809: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 810: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 811: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 812: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 813: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 814: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 815: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 816: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 817: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 818: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 819: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 820: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 821: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 822: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 823: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 824: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 825: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 826: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 827: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 828: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 829: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 830: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 831: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 832: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 833: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 834: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 835: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 836: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 837: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 838: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 839: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 840: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 841: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 842: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 843: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 844: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 845: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 846: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 847: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 848: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 849: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 850: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 851: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 852: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 853: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 854: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 855: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 856: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 857: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 858: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 859: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 860: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 861: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 862: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 863: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 864: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 865: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 866: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 867: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 868: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 869: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 870: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 871: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 872: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 873: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 874: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 875: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 876: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 877: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 878: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 879: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 880: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 881: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 882: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 883: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 884: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 885: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 886: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 887: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 888: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 889: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 890: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 891: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 892: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 893: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 894: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 895: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 896: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 897: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 898: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 899: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 900: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 901: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 902: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 903: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 904: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 905: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 906: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 907: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 908: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 909: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 910: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 911: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 912: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 913: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 914: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 915: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 916: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 917: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 918: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 919: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 920: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 921: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 922: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 923: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 924: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 925: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 926: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 927: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 928: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 929: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 930: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 931: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 932: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 933: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 934: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 935: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 936: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 937: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 938: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 939: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 940: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 941: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 942: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 943: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 944: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 945: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 946: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 947: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 948: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 949: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 950: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 951: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 952: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 953: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 954: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 955: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 956: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 957: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 958: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 959: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 960: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 961: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 962: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 963: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 964: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 965: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 966: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 967: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 968: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 969: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 970: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 971: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 972: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 973: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 974: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 975: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 976: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 977: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 978: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 979: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 980: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 981: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 982: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 983: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 984: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 985: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 986: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 987: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 988: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 989: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 990: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 991: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 992: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 993: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 994: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 995: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 996: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 997: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 998: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Итерация 999: Пустая или нулевая бутстрап-выборка. Пропускаем.
# Наблюдаемая разница средних: nan
# p-значение: nan
#
# --------------------------------------------------

# %%
print("Стратификация:")

if 'strata' not in data.columns:
    print("Столбец 'strata' отсутствует в данных. Невозможно провести стратификацию.")
else:

    def stratified_t_test(data, strata_col='strata', group_col='group', metric_col='metrica'):
        """
        Проводит стратифицированный t-тест для сравнения двух групп.
        """
        stratified_results = []
        strata_values = data[strata_col].unique()
        overall_mean = data[metric_col].mean()

        for strata in strata_values:
            control_strata = data[(data[group_col] == 'control') & (data[strata_col] == strata)][metric_col]
            test_strata = data[(data[group_col] == 'test') & (data[strata_col] == strata)][metric_col]

            if len(control_strata) == 0 or len(test_strata) == 0:
                print(f"Предупреждение: Страта '{strata}' содержит недостаточно данных для обеих групп. Пропускается.")
                continue

            control_strata_adj = control_strata - control_strata.mean() + overall_mean
            test_strata_adj = test_strata - test_strata.mean() + overall_mean

            t_statistic, p_value = perform_t_test(pd.DataFrame({'metrica': control_strata_adj}), pd.DataFrame({'metrica': test_strata_adj}))
            stratified_results.append({'strata': strata, 't_statistic': t_statistic, 'p_value': p_value})

        p_values = [result['p_value'] for result in stratified_results if not np.isnan(result['p_value'])]
        if not p_values:
            print("Нет валидных p-value для объединения.")
            return np.nan, stratified_results

        chi2_statistic = -2 * np.sum(np.log(p_values))
        degrees_freedom = 2 * len(p_values)
        combined_p_value = 1 - stats.chi2.cdf(chi2_statistic, degrees_freedom)

        return combined_p_value, stratified_results


    combined_p_value_stratified, stratified_results = stratified_t_test(data)
    print(f"Объединенное p-значение (стратификация): {combined_p_value_stratified:.3f}")
    print("\nРезультаты по стратам:")
    for result in stratified_results:
        print(f"Страта: {result['strata']}, t-статистика: {result['t_statistic']:.3f}, p-значение: {result['p_value']:.3f}")


print("\n--------------------------------------------------\n")
# Out:
# Стратификация:
# Столбец 'strata' отсутствует в данных. Невозможно провести стратификацию.
#
# --------------------------------------------------

# %%
print("CUPED:")

if 'past_history' not in data['group'].unique():
    print("Ошибка: В данных отсутствует 'past_history' для применения CUPED.  Убедитесь, что она указана в столбце 'group'.")
else:
    # 1. Расчет Theta
    past_history_group = data[data['group'] == 'past_history']
    test_group_cuped = data[data['group'] == 'test']
    control_group_cuped = data[data['group'] == 'control']

    if len(test_group_cuped) == 0 or len(past_history_group) == 0 or len(control_group_cuped) == 0:
        print("Ошибка: Отсутствуют данные в группах 'test', 'control' или 'past_history'. CUPED не может быть применен.")
    else:
        cov = np.cov(control_group_cuped['metrica'], past_history_group['metrica'])[0][1]
        var = np.var(past_history_group['metrica'])
        theta = cov / var

        # 2. CUPED Adjustment
        data['metric_cuped'] = data['metrica']

        data.loc[data['group'].isin(['test', 'control']), 'metric_cuped'] = data.loc[data['group'].isin(['test', 'control']), 'metrica'] - theta * (data.loc[data['group'].isin(['test', 'control']), 'metrica'] - past_history_group['metrica'].mean())

        # 3. Проведение t-теста на скорректированных данных
        control_group_cuped = data[data['group'] == 'control']
        test_group_cuped = data[data['group'] == 'test']
        t_statistic_cuped, p_value_cuped = perform_t_test(control_group_cuped, test_group_cuped)

        print(f"Theta: {theta:.3f}")
        print(f"t-статистика (CUPED): {t_statistic_cuped:.3f}")
        print(f"p-значение (CUPED): {p_value_cuped:.3f}")
# Out:
# CUPED:
# Ошибка: В данных отсутствует 'past_history' для применения CUPED.  Убедитесь, что она указана в столбце 'group'.
